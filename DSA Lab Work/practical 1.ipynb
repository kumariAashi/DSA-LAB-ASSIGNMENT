# %%
arr=[10,20,30,40]
for i in range (len(arr)):
 print("Element:", arr[i], "Position:", i )
# Out:
# Element: 10 Position: 0
# Element: 20 Position: 1
# Element: 30 Position: 2
# Element: 40 Position: 3

# %%
arr=[10,20,30,40]
for i in range(len(arr)):
 print("element :",arr[i],"address:",id(arr[i]))
# Out:
# element : 10 address: 140726522377416
# element : 20 address: 140726522377736
# element : 30 address: 140726522378056
# element : 40 address: 140726522378376

# %%
from array import array
arr=array('i', [10,20,30,40])
print("memory addresses.")
for i in range(len(arr)):
      print(f"index {i} -> address {arr.buffer_info()[0] + i * arr.itemsize}")
# Out:
# memory addresses.
# index 0 -> address 2875810747728
# index 1 -> address 2875810747732
# index 2 -> address 2875810747736
# index 3 -> address 2875810747740
