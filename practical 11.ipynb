# %%
#Column-Major representation
arr=[
    [1,2,3],
    [4,5,6],
    
]
print("element in col-major order:")
for j in range(len(arr[0])):
    for i in range(len(arr)):
        print(arr[i][j], end=" ")
# Out:
# element in col-major order:
# 1 4 2 5 3 6
